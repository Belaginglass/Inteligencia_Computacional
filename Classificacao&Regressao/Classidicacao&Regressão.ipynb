# %% [markdown]
# <a href="https://colab.research.google.com/github/Belaginglass/Inteligencia_Computacional/blob/master/Classidicacao%26Regress%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Classificação

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_iris

# %%
from ucimlrepo import fetch_ucirepo

# %%
iris = fetch_ucirepo(id=53)

X = iris.data.features
y = iris.data.targets


df = pd.concat([X, y], axis=1)
display(df.head())
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
from pandas.api.types import is_numeric_dtype

for col in df.columns:
    if is_numeric_dtype(df[col]):
        print('%s:' % (col))
        print('\t Mean = %.2f' % df[col].mean())
        print('\t Standard deviation = %.2f' % df[col].std())
        print('\t Minimum = %.2f' % df[col].min())
        print('\t Maximum = %.2f' % df[col].max())
# Out:
# sepal length:
# 	 Mean = 5.84
# 	 Standard deviation = 0.83
# 	 Minimum = 4.30
# 	 Maximum = 7.90
# sepal width:
# 	 Mean = 3.05
# 	 Standard deviation = 0.43
# 	 Minimum = 2.00
# 	 Maximum = 4.40
# petal length:
# 	 Mean = 3.76
# 	 Standard deviation = 1.76
# 	 Minimum = 1.00
# 	 Maximum = 6.90
# petal width:
# 	 Mean = 1.20
# 	 Standard deviation = 0.76
# 	 Minimum = 0.10
# 	 Maximum = 2.50

# %%
X = df.drop(columns=['class'])
y = df['class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20,random_state=123)

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)

# %%
P = [1,1,3,3]
print(knn.predict([P]))
print(knn.predict([[1,1,1,3]]))
print(knn.predict([[5,3,5,1]]))

# %% [markdown]
# ##Regressão

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
url = "https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv"
housing = pd.read_csv(url)

df = pd.DataFrame(housing)
display(df.head())
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
X = df[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax','ptratio', 'b', 'lstat']]
y = df['medv']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
clf = LinearRegression()
clf.fit(X_train, y_train)

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.6733825506400162
